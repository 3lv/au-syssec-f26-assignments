# %%
import rsa_pps

# %%
(n, e, d) = rsa_pps.generate_rsa_key()
message = "Ana are mere".encode()

sig = rsa_pps.rsa_pss_sign(message, n, d)
print(message, sig)

rsa_pps.rsa_pss_verify(message, sig, n, e, )
# Out:
# b'Ana are mere' b'p\xabe7\xe4D\r\x8f\xefcC(\xd3S\xe4_\xa8\x1c2.\x1b\x1d\xdd\xc2\xa3\xbf\xc3\x86~\xab\xae\x19\xab\xc6\x1d\xc1J\xc8\x9e;\x8c\x03v\xbf\xbd.kE?X\xeb\'\x8d\x07^\xe6J\x85\x08\x8c\xfbh\xe3F\x13\xad>\xf7\xa7\xab\x01\xfcL\xd8\xaf\x9c\x9e\x157\xd7\xb2\xfd\xe9\xf1\xdc.\x07\xce\x93\xbf\xe5;\xc1[b\x81_\xc6x\xe4ZhU"5\x9c\xf1\x8a\xf3e\xe2\x8c6F\xd2v\t\xef"a\x84,\x873\xb6\x85X;\x90s\xb1\xb9T\x0c\x9eN&\x91\xe3\x11\xd7\x914\xdc\xd2K\x0f\xf7\xb9L\xc4\x02\x12\xb5\x19\x80_^\xb8S&GzhK\xd9\x18\x89\xa0|H\x81\xa7rD`\xe0\xd8\xa1\x181\xb4\xe6\xef\xfd#\xf5\n\xc59\x03\xb7\xab\x14i\xde\xe1p\xc4\xd6]tP\xfc\xba\x02U\xcf7\x91\xf9\x8e \xc7\\\xb5\xc2!\x908<\xaf\xe1O\x18\x8d\x96\xb2\xb0\xcd\xc9\x86\x02\x80\x9c\x81\xba\xc9\xd9\xe1\xb80(\n\xec\xe7\xd9l<\xcf\x00\x87i.{z9M\xac+\xf6\x1d\xf2r\xaf\x8e\xb0oC\xc9r$\xf7\xfc\x1b\xec\xd4\xae\x08$\xcd\x01xM\x0fI\xc3\x15\x83\xfb\x90c\x88\x97.\xc3\x99\x1b\xd1\xb6\x12\xbew\x91q\n\xcb\x19\xa0\x00\x1f\x11Nf`:\x19\xebC\x0f\xdc\x9c\x1f\x9e\x9fi\x897\xbf\xfd\x04=\x00\xe4\xf
# ...

# %%
sig = pow(17, d, n)
m = pow(sig, e, n)
print(sig)
print(m)
# Out:
# ...
# 17
